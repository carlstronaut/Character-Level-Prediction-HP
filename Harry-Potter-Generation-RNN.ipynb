# %%
import torch
from torch import nn
import torch.nn.functional as F 
import numpy as np
import random
import matplotlib.pyplot as plt

# One-hot encoding matrix with dim (seq_length,K)
# (creating one hot encoded rows for each character in a sequence )
def one_hot(text_seq):
    data = np.zeros((len(text_seq), K), dtype=np.float32)
    for i in range(len(text_seq)):
        char_as_int = text_seq[i]
        data[i][char_as_int] = 1
    return data

def get_all_sequences(book_text):
    # Translate text to integers
    book_as_ints = np.array([c2i[c] for c in book_text])
    n_seq = len(book_as_ints)//seq_length
    book_text = book_text[:n_seq*seq_length]
    batches = []
    for i in range(0, len(book_text), seq_length):
        batches.append(one_hot(book_as_ints[i:i+seq_length]))
    return np.array(batches, dtype=np.float32)

# one_hots = (seq_length, K)
def one_hot_to_txt(one_hots):
    chars = []
    for arr in one_hots:
        idx = np.where(arr == 1)[0][0]
        chars.append(i2c[idx])
    return ''.join(chars)

def one_hot_to_ind(one_hots):
    indices = []
    for arr in one_hots:
        indices.append(np.where(arr==1)[0][0])
    return np.array(indices)

def get_next_char(s):
    s = nn.functional.softmax(s, dim=1)
    l = torch.cumsum(s, dim=1)
    a = random.uniform(0,1)
    ls = (l - a).cpu().detach().numpy()
    #print(ls)
    idx = np.where(ls > 0)
    idx = idx[1][0]
    onehot = np.zeros(K, dtype=np.float32)
    onehot[idx] = 1
    onehot = torch.from_numpy(onehot).view(1,1,K).float().to(device)
    return idx, i2c[idx], onehot

def synthesize_text(model, char, length):
    model.eval()
    generated_seq = [char]
    x0 = np.zeros(K, dtype=np.float32)
    x0[c2i[char]] = 1
    x0 = torch.from_numpy(x0)
    x0 = x0.view(1,1,K).to(device)
    hidden = model.init_hidden(1)
    for i in range(length):
        #print("x0 shape: " + str(x0.shape))
        #print("hidden shape: " + str(hidden.shape))
        s, hidden = model(x0, hidden)
        i, c, x0 = get_next_char(s)
        generated_seq.append(c)
    model.train()
    return ''.join(generated_seq)

# Vanilla RNN for character-level generation
class VanillaRNN(nn.Module):
    def __init__(self, input_size, output_size, hidden_size, n_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.n_layers = n_layers
        self.rnn = nn.RNN(input_size, hidden_size, n_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, len(chars))

    def forward(self, x, hidden):
        # Passing in the input and hidden state into the model and obtaining outputs
        out, hidden = self.rnn(x, hidden)
        # Reshaping the outputs such that it can be fit into the fully connected layer
        out = out.contiguous().view(-1, self.hidden_size)
        out = self.fc(out)

        return out, hidden

    def init_hidden(self, batch_size):
        # This method generates the first hidden state of zeros which we'll use in the forward pass
        # We'll send the tensor holding the hidden state to the device we specified earlier as well
        if cuda_available:
            hidden = torch.zeros(self.n_layers, batch_size, self.hidden_size).cuda()
        else:
            hidden = torch.zeros(self.n_layers, batch_size, self.hidden_size)
        return hidden

# Saves loss and generted text during training    
lossarr = []
strarr = []
def train(model, n_epochs, clip, debug = 0, steps_during_debug=2):
    model.train()
    update_step = 0
    smooth_loss = 0
    debug = 0
    #print("Numbers of update steps per epoch: " + str(x.shape[0]))
    for epoch in range(1, n_epochs + 1):
        #OBSSS!!! HARDCODED BATCH MIGHT CHANGE LATER
        hidden = model.init_hidden(1)
        for i in range(x.shape[0]):
            if debug: 
                if(i > steps_during_debug): 
                    break    
            # Detatching hidden state from the computational graph 
            # (see truncated back propagation through time) such that
            # the graph doesn't become super big, slowing down computations
            # and exploding the gradient. 
            
            # Note however that the hidden state VALUE will still be inherited
            # We just say that it doesn't depend on previous hidden states
            hidden.detach_()
            hidden = hidden.to(device)
            
            # Clear gradients between update steps, won't be cleared automatically. 
            opt.zero_grad() 
            
            #Remember that input should have dimensions (batch_size, seq_size, number_of_classes)
            seq = x[i]
            seq = torch.from_numpy(seq).view(1,seq_length,K)
            #if cuda_available: 
            seq = seq.to(device)
            #print("seq shape: " + str(seq.shape))        

            #Should have shape (25) (not (25,80))
            target = y[i]
            target = one_hot_to_ind(target)
            target = torch.from_numpy(target)
            target = target.to(device)
            #print("target shape: " + str(target.shape))

            output, hidden = model(seq, hidden)
            loss = criterion(output, target)
            
            if update_step == 0:
                smooth_loss = loss
            else:
                smooth_loss = smooth_loss*0.999 + loss*0.001
            if update_step%500 == 0:
                lossarr.append(smooth_loss.item())
                print(len(lossarr))
                print("\n\n===========================================================================================")
                print("Update Step: " + str(update_step) +"/" + str(x.shape[0]) + ", " + str((update_step/x.shape[0])*100) +"%")
                print(str(smooth_loss))
                print("========================================= TEXT ============================================")
                print(synthesize_text(model, 'H', 50))
                print("===========================================================================================")
            if update_step%20000 == 0:
                strarr.append(synthesize_text(model, 'H', 50))
            
            # BPTT 
            loss.backward() 
            # Clip gradients such that they don't explode
            nn.utils.clip_grad_norm_(model.parameters(), clip) 
            # Update the gradients
            opt.step() 
            update_step += 1
    model.eval()

# %%
cuda_available = torch.cuda.is_available()
if cuda_available:
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("Running on: " + str(device))

# Open file and get text
file = open("Clean_All_Books.txt", "r", encoding="utf8")
book = file.read()
file.close()

# Tokenize chars in text
chars = list(set(book))
chars.sort()
i2c = dict(enumerate(chars))
c2i = {i2c[i]: i for i in i2c.keys()}

# Hyper-parameters
# Num hidden nodes
m = 100
# Batch Size
seq_length = 25
# Number of chars
K = len(chars)
# Learning rate
eta = 0.1
      
model = VanillaRNN(input_size = K, output_size = K, hidden_size = m, n_layers=1)
model.to(device)
criterion = nn.CrossEntropyLoss()
opt = torch.optim.Adagrad(model.parameters(), lr=eta)
# model.parameters are all params e.g U, V, b, c etc, see print below
#for param in list(model.parameters()):
#    print(param.shape)
x = get_all_sequences(book)
#print(np.shape(x))
#print(one_hot_to_txt(x[0]))
# If even number of chars (in relation to seq_length), first char will be last target
y = get_all_sequences(book[1:] + book[0])
# Out:
# Running on: cuda

# %%
train(model, 2, 5)
# Out:
# Numbers of update steps per epoch: 256485
# 1
#
#
# ===========================================================================================
# Update Step: 0/256485, 0.0%
# tensor(4.5091, device='cuda:0', grad_fn=<NllLossBackward>)
# ========================================= TEXT ============================================
# Hk8XC2,LBu—~QVq:Qg4txj\C%0j!Ov*welwR’
# R1:&?NG4R"E,d
# ===========================================================================================
# 2
#
#
# ===========================================================================================
# Update Step: 500/256485, 0.1949431740647601%
# tensor(3.9956, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H, . d a’o, ee toe opabe ad n fly
# uie cey, ageh n
# ===========================================================================================
# 3
#
#
# ===========================================================================================
# Update Step: 1000/256485, 0.3898863481295202%
# tensor(3.4975, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hw hotipt’ore’selad fethes in Cro, Doothonithetunt
# ===========================================================================================
# 4
#
#
# ===========================================================================================
# Update Step: 1500/256485, 0.5848295221942803%
# tensor(3.1111, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hen., ommufveod thamm sacon’d capumin’conb t Tord ’
# ===========================================================================================
# 5
#
#
# ===========================================================================================
# Update Step: 2000/256485, 0.7797726962590404%
# tensor(2.8525, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harlked,,”””
# rediy goabll tars, is bis Dus
#
# fivde
# ===========================================================================================
# 6
#
#
# ===========================================================================================
# Update Step: 2500/256485, 0.9747158703238007%
# tensor(2.6648, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HoTGawt atoutey licge arf bedpurlit
# ouccus starnaO
# ===========================================================================================
# 7
#
#
# ===========================================================================================
# Update Step: 3000/256485, 1.1696590443885606%
# tensor(2.5507, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Had avard coud!ed Hasliy ferkabeoskey, svedled,” sh
# ===========================================================================================
# 8
#
#
# ===========================================================================================
# Update Step: 3500/256485, 1.3646022184533209%
# tensor(2.4967, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har. souleneling
# lithe sew sor mliw’s he taghill S
# ===========================================================================================
# 9
#
#
# ===========================================================================================
# Update Step: 4000/256485, 1.5595453925180809%
# tensor(2.4508, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H’t
# peot could Ha cave salit thereley, soatare, Sy
# ===========================================================================================
# 10
#
#
# ===========================================================================================
# Update Step: 4500/256485, 1.754488566582841%
# tensor(2.3869, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Ha
# iy in erapad.”
# “Dund yeatd,. Ro the’ged
# f hin
# ===========================================================================================
# 11
#
#
# ===========================================================================================
# Update Step: 5000/256485, 1.9494317406476014%
# tensor(2.3464, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He” in gleugm masing
# awhint Mutwer heel
# Iupeedtan
# ===========================================================================================
# 12
#
#
# ===========================================================================================
# Update Step: 5500/256485, 2.1443749147123614%
# tensor(2.2916, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Ha wey’ the canw there the hamd hift
# noo there cus
# ===========================================================================================
# 13
#
#
# ===========================================================================================
# Update Step: 6000/256485, 2.339318088777121%
# tensor(2.2666, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Horryye hon Hiars,
# thein thiptreyeyshee, out int
#
# ===========================================================================================
# 14
#
#
# ===========================================================================================
# Update Step: 6500/256485, 2.534261262841882%
# tensor(2.2354, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harre to
# HarryKbed on shered of concor licks wof,
# ===========================================================================================
# 15
#
#
# ===========================================================================================
# Update Step: 7000/256485, 2.7292044369066417%
# tensor(2.2287, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Haly, ald, pocle Hatrer a mpotry ass ar be sred”’ t
# ===========================================================================================
# 16
#
#
# ===========================================================================================
# Update Step: 7500/256485, 2.924147610971402%
# tensor(2.2227, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hirryyies eore
# Whears a beuwn. one-feo he ber.
# Th
# ===========================================================================================
# 17
#
#
# ===========================================================================================
# Update Step: 8000/256485, 3.1190907850361618%
# tensor(2.2005, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hat aid
# Wacly the
# Srond, on nepbont doa
# s ith a
# ===========================================================================================
# 18
#
#
# ===========================================================================================
# Update Step: 8500/256485, 3.314033959100922%
# tensor(2.1792, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hored unlty dors floul frounonithe wes who the on h
# ===========================================================================================
# 19
#
#
# ===========================================================================================
# Update Step: 9000/256485, 3.508977133165682%
# tensor(2.1526, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harver. IN Ccoung ver dicane beett the e lilf got a
# ===========================================================================================
# 20
#
#
# ===========================================================================================
# Update Step: 9500/256485, 3.7039203072304425%
# tensor(2.1432, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hatet hey that ryanvery his fork, Beveed ou.
# “Woud
# ===========================================================================================
# 21
#
#
# ===========================================================================================
# Update Step: 10000/256485, 3.8988634812952028%
# tensor(2.1272, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hars agmulldt bet you thot.
# En Wo.”
# “Yous.
# “Dull
# ===========================================================================================
# 22
#
#
# ===========================================================================================
# Update Step: 10500/256485, 4.093806655359963%
# tensor(2.0862, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HO’rdaigh weararer haghe thee hermy
# aver,
# Bond we
# ===========================================================================================
# 23
#
#
# ===========================================================================================
# Update Step: 11000/256485, 4.288749829424723%
# tensor(2.0873, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harray
# flockes us — woslus exow at tasd
# saster, t
# ===========================================================================================
# 24
#
#
# ===========================================================================================
# Update Step: 11500/256485, 4.483693003489483%
# tensor(2.0800, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harrit hey none
# peelleste hes him, Harrexre was,
#
# ===========================================================================================
# 25
#
#
# ===========================================================================================
# Update Step: 12000/256485, 4.678636177554242%
# tensor(2.0690, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harring, rowdore, it ang sullows
# the wos mad, the
# ===========================================================================================
# 26
#
#
# ===========================================================================================
# Update Step: 12500/256485, 4.873579351619003%
# tensor(2.0397, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HT’rmye
# I Ned is sulb Harry hors Cfaile the sol’s
# ===========================================================================================
# 27
#
#
# ===========================================================================================
# Update Step: 13000/256485, 5.068522525683764%
# tensor(2.0302, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Herly? “Sieveridly tene thit plorets on nothing has
# ===========================================================================================
# 28
#
#
# ===========================================================================================
# Update Step: 13500/256485, 5.263465699748523%
# tensor(2.0364, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Haon’s hon in poml you whareashing serourw whey lat
# ===========================================================================================
# 29
#
#
# ===========================================================================================
# Update Step: 14000/256485, 5.458408873813283%
# tensor(2.0193, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harys letrisoint
# botales ot
# hish was of teruid, l
# ===========================================================================================
# 30
#
#
# ===========================================================================================
# Update Step: 14500/256485, 5.653352047878044%
# tensor(2.0110, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry the Bilehw ar
# geed puld ded to ked anke pak,
# ===========================================================================================
# 31
#
#
# ===========================================================================================
# Update Step: 15000/256485, 5.848295221942804%
# tensor(2.0108, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# His withu wef saif noem wis ow
# pant there sich fac
# ===========================================================================================
# 32
#
#
# ===========================================================================================
# Update Step: 15500/256485, 6.043238396007563%
# tensor(2.0039, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H....... shat ter often onder bee ougviss offy.
# “J
# ===========================================================================================
# 33
#
#
# ===========================================================================================
# Update Step: 16000/256485, 6.2381815700723235%
# tensor(1.9771, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H.”’ erone on Ninnt hot “Learr hes thoug. It sturn
# ===========================================================================================
# 34
#
#
# ===========================================================================================
# Update Step: 16500/256485, 6.433124744137084%
# tensor(1.9623, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Her ere tei hare
# eakd at and loon, ““Mvamled
# they
# ===========================================================================================
# 35
#
#
# ===========================================================================================
# Update Step: 17000/256485, 6.628067918201844%
# tensor(1.9616, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE Lris m.. W. snel
# caces. The tlet inch seapedshe
# ===========================================================================================
# 36
#
#
# ===========================================================================================
# Update Step: 17500/256485, 6.823011092266603%
# tensor(1.9681, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harre you hed jow. Ay Againg fled
# surd, Harry you
# ===========================================================================================
# 37
#
#
# ===========================================================================================
# Update Step: 18000/256485, 7.017954266331364%
# tensor(2.0095, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry. Dare had ntond it of the Vermow the wass — B
# ===========================================================================================
# 38
#
#
# ===========================================================================================
# Update Step: 18500/256485, 7.212897440396125%
# tensor(2.0117, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Ha.
# doung congdo’s on they yee Potixgh ounn —
# Iak
# ===========================================================================================
# 39
#
#
# ===========================================================================================
# Update Step: 19000/256485, 7.407840614460885%
# tensor(2.0206, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harrye goterirg revim ofly
# seining Herry domb, the
# ===========================================================================================
# 40
#
#
# ===========================================================================================
# Update Step: 19500/256485, 7.602783788525645%
# tensor(1.9923, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE.
# ““Not you of houts, she Dontuslnoming dreych
#
# ===========================================================================================
# 41
#
#
# ===========================================================================================
# Update Step: 20000/256485, 7.7977269625904055%
# tensor(2.0060, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harrying had the kbom comlyoowtanengle nothing magl
# ===========================================================================================
# 42
#
#
# ===========================================================================================
# Update Step: 20500/256485, 7.992670136655165%
# tensor(2.0141, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harres mewfile.
# “They’rd
# of statar onet dins byop
# ===========================================================================================
# 43
#
#
# ===========================================================================================
# Update Step: 21000/256485, 8.187613310719925%
# tensor(2.0024, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry sho geee sigch, ghougking wald lash
# jutt
# op
# ===========================================================================================
# 44
#
#
# ===========================================================================================
# Update Step: 21500/256485, 8.382556484784685%
# tensor(2.0084, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H. Wyin tro got park op Md farriedly, to to but
#
# p
# ===========================================================================================
# 45
#
#
# ===========================================================================================
# Update Step: 22000/256485, 8.577499658849446%
# tensor(1.9838, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Ha.
# Yeus Hapry punet mall and therins warst shasye
# ===========================================================================================
# 46
#
#
# ===========================================================================================
# Update Step: 22500/256485, 8.772442832914205%
# tensor(1.9775, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He tre baus the he whutceins.
# he they thei-shing a
# ===========================================================================================
# 47
#
#
# ===========================================================================================
# Update Step: 23000/256485, 8.967386006978966%
# tensor(2.0015, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry and Ron.
# “Wablinc; — ” us theren’s a it.
# “I
# ===========================================================================================
# 48
#
#
# ===========================================================================================
# Update Step: 23500/256485, 9.162329181043726%
# tensor(2.0099, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harrowe out foone. you Harry in opply call of fould
# ===========================================================================================
# 49
#
#
# ===========================================================================================
# Update Step: 24000/256485, 9.357272355108485%
# tensor(2.0040, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He
# y ully was tevem. “The gat abratilged as vert f
# ===========================================================================================
# 50
#
#
# ===========================================================================================
# Update Step: 24500/256485, 9.552215529173246%
# tensor(1.9792, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hagry and. Barne’s yoar
# bun to and dond —
# couldel
# ===========================================================================================
# 51
#
#
# ===========================================================================================
# Update Step: 25000/256485, 9.747158703238005%
# tensor(1.9762, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE ryid Ron. Allfars, yey it?” shousesmon a loume’s
# ===========================================================================================
# 52
#
#
# ===========================================================================================
# Update Step: 25500/256485, 9.942101877302765%
# tensor(1.9963, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Ho sand wat
# and the frabed at hadded him. H. Harry
# ===========================================================================================
# 53
#
#
# ===========================================================================================
# Update Step: 26000/256485, 10.137045051367528%
# tensor(1.9852, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harryeen ghtile. “Ai Pe!”
# “I you’shrey and the ite
# ===========================================================================================
# 54
#
#
# ===========================================================================================
# Update Step: 26500/256485, 10.331988225432287%
# tensor(1.9817, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H. I to had be
# dowche it ily was poodling,
# qurrt.
# ===========================================================================================
# 55
#
#
# ===========================================================================================
# Update Step: 27000/256485, 10.526931399497046%
# tensor(1.9615, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HYrode syougle. I’velly dent aspeapped shome letred
# ===========================================================================================
# 56
#
#
# ===========================================================================================
# Update Step: 27500/256485, 10.721874573561808%
# tensor(1.9570, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry
# gurasning dew pmabuthom and ant’s whed thwat
# ===========================================================================================
# 57
#
#
# ===========================================================================================
# Update Step: 28000/256485, 10.916817747626567%
# tensor(1.9391, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary — slasarm tlapgher with a drand lowers had was
# ===========================================================================================
# 58
#
#
# ===========================================================================================
# Update Step: 28500/256485, 11.111760921691328%
# tensor(1.9276, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE. Do bin’t he of an laor Mackine sor, the and. Th
# ===========================================================================================
# 59
#
#
# ===========================================================================================
# Update Step: 29000/256485, 11.306704095756087%
# tensor(1.9372, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hared ingle woleed. “Bray.
# m’per It canghaed sear.
# ===========================================================================================
# 60
#
#
# ===========================================================================================
# Update Step: 29500/256485, 11.501647269820847%
# tensor(1.9275, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry we
# an tam fert od though? Weacked. Handine r
# ===========================================================================================
# 61
#
#
# ===========================================================================================
# Update Step: 30000/256485, 11.696590443885608%
# tensor(1.9296, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harrie stohine ir alry fort.”
# He decn, then’s one
# ===========================================================================================
# 62
#
#
# ===========================================================================================
# Update Step: 30500/256485, 11.891533617950367%
# tensor(1.9193, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He llede came some. Whis that mise. “I’f you oaredr
# ===========================================================================================
# 63
#
#
# ===========================================================================================
# Update Step: 31000/256485, 12.086476792015127%
# tensor(1.9196, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H..”
# “Droy her mogloy the
# quing a cantinh Slather
# ===========================================================================================
# 64
#
#
# ===========================================================================================
# Update Step: 31500/256485, 12.281419966079888%
# tensor(1.9103, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harrly a.”
# “Oovered. “Yet intiding ’h hocksow spac
# ===========================================================================================
# 65
#
#
# ===========================================================================================
# Update Step: 32000/256485, 12.476363140144647%
# tensor(1.9171, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He wny
# hart hamer the him we reacabeme, a wnives w
# ===========================================================================================
# 66
#
#
# ===========================================================================================
# Update Step: 32500/256485, 12.671306314209406%
# tensor(1.9062, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry in with sain to” to theme the becting doing
#
# ===========================================================================================
# 67
#
#
# ===========================================================================================
# Update Step: 33000/256485, 12.866249488274168%
# tensor(1.8993, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hardy to over, sitting lioht.”
# Harry dick the migr
# ===========================================================================================
# 68
#
#
# ===========================================================================================
# Update Step: 33500/256485, 13.061192662338927%
# tensor(1.9081, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry you malllis bected the feme would to he Hagri
# ===========================================================================================
# 69
#
#
# ===========================================================================================
# Update Step: 34000/256485, 13.256135836403688%
# tensor(1.8824, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry be seme
# yet he hand some ald theled.
# “Oun,
# ===========================================================================================
# 70
#
#
# ===========================================================================================
# Update Step: 34500/256485, 13.451079010468447%
# tensor(1.8754, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harryougow twromoor?”
# Who tome Slass!!”
# Ars exaly
# ===========================================================================================
# 71
#
#
# ===========================================================================================
# Update Step: 35000/256485, 13.646022184533207%
# tensor(1.8718, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He ho chound trongy with to a argon’t w furs not ..
# ===========================================================================================
# 72
#
#
# ===========================================================================================
# Update Step: 35500/256485, 13.840965358597968%
# tensor(1.8558, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harowe e’ve aud wile weowe do. He mores excanted.”
# ===========================================================================================
# 73
#
#
# ===========================================================================================
# Update Step: 36000/256485, 14.035908532662727%
# tensor(1.8531, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry un dny?”
# “Od said. Locks. “I reess stalle. R
# ===========================================================================================
# 74
#
#
# ===========================================================================================
# Update Step: 36500/256485, 14.230851706727488%
# tensor(1.8767, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hat you ell
# hext a dackly a prow?”
# Hurring with a
# ===========================================================================================
# 75
#
#
# ===========================================================================================
# Update Step: 37000/256485, 14.42579488079225%
# tensor(1.8740, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Ht.
# on in anow to ask’s on tilu,” eveed look drepp
# ===========================================================================================
# 76
# ===========================================================================================
# Update Step: 37500/256485, 14.62073805485701%
# tensor(1.8828, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He
# ret corf theided it vereme
# ald allye, they for
# ===========================================================================================
# 77
#
#
# ===========================================================================================
# Update Step: 38000/256485, 14.81568122892177%
# tensor(1.8875, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry FAnden, and Pippeen moved they off
# Dumbly. T
# ===========================================================================================
# 78
#
#
# ===========================================================================================
# Update Step: 38500/256485, 15.010624402986531%
# tensor(1.9322, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry bambouce in forenage the wind the Drizing lis
# ===========================================================================================
# 79
#
#
# ===========================================================================================
# Update Step: 39000/256485, 15.20556757705129%
# tensor(1.9427, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harryesturd Unnh to a
# at that e suve honly the rea
# ===========================================================================================
# 80
#
#
# ===========================================================================================
# Update Step: 39500/256485, 15.40051075111605%
# tensor(1.9356, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE Prot. I mago inge sot of hold har glapay. sarm.”
# ===========================================================================================
# 81
#
#
# ===========================================================================================
# Update Step: 40000/256485, 15.595453925180811%
# tensor(1.9347, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary but
# tame erne — it a
# to crade
# he had deam h
# ===========================================================================================
# 82
#
#
# ===========================================================================================
# Update Step: 40500/256485, 15.79039709924557%
# tensor(1.9554, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary. Bustimefwing avist of eythirgurdnigh aus Cunt
# ===========================================================================================
# 83
#
#
# ===========================================================================================
# Update Step: 41000/256485, 15.98534027331033%
# tensor(1.9716, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harrowed throws conent ray. I he’d.
# An to ye pulad
# ===========================================================================================
# 84
#
#
# ===========================================================================================
# Update Step: 41500/256485, 16.18028344737509%
# tensor(1.9427, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Her. Harry.
# Harry eared. ...”
# “Aed, look..
# “ the
# ===========================================================================================
# 85
#
#
# ===========================================================================================
# Update Step: 42000/256485, 16.37522662143985%
# tensor(1.9168, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry telliserl’s seeved to them at plize for
# mook
# ===========================================================================================
# 86
#
#
# ===========================================================================================
# Update Step: 42500/256485, 16.57016979550461%
# tensor(1.8877, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE...
# “He
# she was Hor, areace, had
# groor a was t
# ===========================================================================================
# 87
#
#
# ===========================================================================================
# Update Step: 43000/256485, 16.76511296956937%
# tensor(1.8567, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hurry it the Wouddhor’s stinighso whappel the
# reap
# ===========================================================================================
# 88
#
#
# ===========================================================================================
# Update Step: 43500/256485, 16.96005614363413%
# tensor(1.8513, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He
# rogin
# Anclled the half they you brow latestter
# ===========================================================================================
# 89
#
#
# ===========================================================================================
# Update Step: 44000/256485, 17.15499931769889%
# tensor(1.8863, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He.
# rou, steant it. Profe goiny he wher tafos you
# ===========================================================================================
# 90
#
#
# ===========================================================================================
# Update Step: 44500/256485, 17.349942491763652%
# tensor(1.8758, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He
# Harfy himdars cheak! Ore of, and look to in her
# ===========================================================================================
# 91
#
#
# ===========================================================================================
# Update Step: 45000/256485, 17.54488566582841%
# tensor(1.8672, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Haris con’s histling int way yed his non thinged th
# ===========================================================================================
# 92
#
#
# ===========================================================================================
# Update Step: 45500/256485, 17.73982883989317%
# tensor(1.8653, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He
# Herpives.” sain wint but miverring the babbed
#
# ===========================================================================================
# 93
#
#
# ===========================================================================================
# Update Step: 46000/256485, 17.934772013957932%
# tensor(1.8816, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary mrowed a
# stavion
# us had
# up to and
# doodlats
# ===========================================================================================
# 94
#
#
# ===========================================================================================
# Update Step: 46500/256485, 18.12971518802269%
# tensor(1.8957, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He
# yer Lothroums furver Blarkly did of thered wors
# ===========================================================================================
# 95
#
#
# ===========================================================================================
# Update Step: 47000/256485, 18.32465836208745%
# tensor(1.8601, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H
# rook Lockud
# becking I knom
# and busunh,” said L
# ===========================================================================================
# 96
#
#
# ===========================================================================================
# Update Step: 47500/256485, 18.519601536152212%
# tensor(1.8533, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary in walk of the killes.
# Aunt neveronees. Int —
# ===========================================================================================
# 97
#
#
# ===========================================================================================
# Update Step: 48000/256485, 18.71454471021697%
# tensor(1.8592, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry. It wasteomingoushedmoon becr thoight beas go
# ===========================================================================================
# 98
#
#
# ===========================================================================================
# Update Step: 48500/256485, 18.90948788428173%
# tensor(1.8420, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H.”
# Hermione.
# fild
# ell the ffope in Ron, that he
# ===========================================================================================
# 99
#
#
# ===========================================================================================
# Update Step: 49000/256485, 19.104431058346492%
# tensor(1.8435, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harro’s hyourh the ont at yourtt. Harry nond Hermig
# ===========================================================================================
# 100
#
#
# ===========================================================================================
# Update Step: 49500/256485, 19.29937423241125%
# tensor(1.8784, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary
# ne the mad, nostids a staring.
# “Doorgateren
# ===========================================================================================
# 101
#
#
# ===========================================================================================
# Update Step: 50000/256485, 19.49431740647601%
# tensor(1.9060, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hear fin’t we kattedrer for withing?”
# “That-ill.
#
# ===========================================================================================
# 102
#
#
# ===========================================================================================
# Update Step: 50500/256485, 19.689260580540772%
# tensor(1.8869, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H’. dor was he. ho had ceffitcofe) up he rous, was
# ===========================================================================================
# 103
#
#
# ===========================================================================================
# Update Step: 51000/256485, 19.88420375460553%
# tensor(1.8843, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE tien’s his trobouted
# his smandored
# the one sli
# ===========================================================================================
# 104
#
#
# ===========================================================================================
# Update Step: 51500/256485, 20.079146928670294%
# tensor(1.8648, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harud
# rosbused spent of hest to mamming said Fudor
# ===========================================================================================
# 105
#
#
# ===========================================================================================
# Update Step: 52000/256485, 20.274090102735055%
# tensor(1.8566, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He “re wis dyowing cor ofs
# firalt —
# “Deckboct sha
# ===========================================================================================
# 106
#
#
# ===========================================================================================
# Update Step: 52500/256485, 20.469033276799813%
# tensor(1.8542, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry a wrout horme the
# gonedy Het.”
# “Moneing. Th
# ===========================================================================================
# 107
#
#
# ===========================================================================================
# Update Step: 53000/256485, 20.663976450864574%
# tensor(1.8643, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H’. Ito hil.
# “Harry in thing to Praver,” haartent
# ===========================================================================================
# 108
#
#
# ===========================================================================================
# Update Step: 53500/256485, 20.858919624929335%
# tensor(1.8644, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harmbess butch bisssorg ook
# mage. he
# his have, un
# ===========================================================================================
# 109
#
#
# ===========================================================================================
# Update Step: 54000/256485, 21.053862798994093%
# tensor(1.8828, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har. The.
# “Kho to Ron come and
# I cars.
# Harry Hon
# ===========================================================================================
# 110
#
#
# ===========================================================================================
# Update Step: 54500/256485, 21.248805973058854%
# tensor(1.8606, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HY’n pagitued she the . .
# round, haarled the Hagri
# ===========================================================================================
# 111
#
#
# ...
# tensor(1.7873, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He rron Porken of Ron, Con was up but le ghouge, co
# ===========================================================================================
# 174
#
#
# ===========================================================================================
# Update Step: 86500/256485, 33.7251691132035%
# tensor(1.8072, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry Harry will ne, noveng stobling as pully. Nevi
# ===========================================================================================
# 175
#
#
# ===========================================================================================
# Update Step: 87000/256485, 33.92011228726826%
# tensor(1.8020, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harly —
# youde frelim!” said Ron sime fagening raya
# ===========================================================================================
# 176
#
#
# ===========================================================================================
# Update Step: 87500/256485, 34.11505546133302%
# tensor(1.7942, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He tir fow hadd puthous, they rogs again, than coul
# ===========================================================================================
# 177
#
#
# ===========================================================================================
# Update Step: 88000/256485, 34.30999863539778%
# tensor(1.8060, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hor ward Harry hat the
# mowind tratter, mos ghor he
# ===========================================================================================
# 178
#
#
# ===========================================================================================
# Update Step: 88500/256485, 34.504941809462544%
# tensor(1.7820, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry seerfing shar going opered doightt bumtruive.
# ===========================================================================================
# 179
#
#
# ===========================================================================================
# Update Step: 89000/256485, 34.699884983527305%
# tensor(1.8036, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HO..
# Har Harruppeening a aliw afowing tain relust
# ===========================================================================================
# 180
#
#
# ===========================================================================================
# Update Step: 89500/256485, 34.89482815759206%
# tensor(1.8240, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry Flent, bafy atillbone list of Harry, you and
# ===========================================================================================
# 181
#
#
# ===========================================================================================
# Update Step: 90000/256485, 35.08977133165682%
# tensor(1.8171, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Haris out ore
# t’ap thed youds’ stree
# smother, nob
# ===========================================================================================
# 182
#
#
# ===========================================================================================
# Update Step: 90500/256485, 35.28471450572158%
# tensor(1.8068, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE boh fer over
# he was beh had uncer, this that a
# ===========================================================================================
# 183
#
#
# ===========================================================================================
# Update Step: 91000/256485, 35.47965767978634%
# tensor(1.8209, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He. I the cereretting of take noser-ght now corce t
# ===========================================================================================
# 184
#
#
# ===========================================================================================
# Update Step: 91500/256485, 35.6746008538511%
# tensor(1.8101, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har. Hall to ange, not lall is
# donn bangelded!”
# “
# ===========================================================================================
# 185
#
#
# ===========================================================================================
# Update Step: 92000/256485, 35.869544027915865%
# tensor(1.8201, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He, least in that that off the oll’s the was
# unvay
# ===========================================================================================
# 186
#
#
# ===========================================================================================
# Update Step: 92500/256485, 36.06448720198062%
# tensor(1.8198, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harrun abvendn’t flapped of this
# smatterfwed and t
# ===========================================================================================
# 187
#
#
# ===========================================================================================
# Update Step: 93000/256485, 36.25943037604538%
# tensor(1.8049, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry, . Hyer have as sime, jooword lisk frot allig
# ===========================================================================================
# 188
#
#
# ===========================================================================================
# Update Step: 93500/256485, 36.45437355011014%
# tensor(1.7839, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har ’N.
# He and stupning — a Greant, ham to sems th
# ===========================================================================================
# 189
#
#
# ===========================================================================================
# Update Step: 94000/256485, 36.6493167241749%
# tensor(1.7928, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry sarye!” Harry car they he snurnen
# his your,”
# ===========================================================================================
# 190
#
#
# ===========================================================================================
# Update Step: 94500/256485, 36.84425989823966%
# tensor(1.7981, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary whotersand tood and watkeling charcroye up on
# ===========================================================================================
# 191
#
#
# ===========================================================================================
# Update Step: 95000/256485, 37.039203072304424%
# tensor(1.7794, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He buthing
# and the At wearmown.”
# Harry out was —
# ===========================================================================================
# 192
#
#
# ===========================================================================================
# Update Step: 95500/256485, 37.23414624636918%
# tensor(1.8037, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry Sarry head, brimit-not you litter gow aloul P
# ===========================================================================================
# 193
#
#
# ===========================================================================================
# Update Step: 96000/256485, 37.42908942043394%
# tensor(1.7960, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har warmever, and to Harry Harry hore pro was yel,
# ===========================================================================================
# 194
#
#
# ===========================================================================================
# Update Step: 96500/256485, 37.6240325944987%
# tensor(1.7891, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harud qurush show. “They,”
# Shrumbed, the moghtlece
# ===========================================================================================
# 195
#
#
# ===========================================================================================
# Update Step: 97000/256485, 37.81897576856346%
# tensor(1.7801, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He Dur. Wiry boncery the Grogger. “Sothy armunly-Pr
# ===========================================================================================
# 196
#
#
# ===========================================================================================
# Update Step: 97500/256485, 38.01391894262822%
# tensor(1.7931, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har
# Crrets,” say lander wifffuech hemssing
# and ha
# ===========================================================================================
# 197
#
#
# ===========================================================================================
# Update Step: 98000/256485, 38.208862116692984%
# tensor(1.8002, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE Ron fieds.
# “IN the Koncelvedn’t the lithered. “
# ===========================================================================================
# 198
#
#
# ===========================================================================================
# Update Step: 98500/256485, 38.403805290757745%
# tensor(1.7508, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hare an’ Harry. Whe mally howle richer andwerm
# tol
# ===========================================================================================
# 199
#
#
# ===========================================================================================
# Update Step: 99000/256485, 38.5987484648225%
# tensor(1.7213, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE Rou’ hald Obessore
# dose exupbearpoon groued the
# ===========================================================================================
# 200
#
#
# ===========================================================================================
# Update Step: 99500/256485, 38.79369163888726%
# tensor(1.7382, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry Klom, blown up in him heas nartly was voup to
# ===========================================================================================
# 201
#
#
# ===========================================================================================
# Update Step: 100000/256485, 38.98863481295202%
# tensor(1.7339, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary
# Thand the his?” said Ned mmintelled and she f
# ===========================================================================================
# 202
#
#
# ===========================================================================================
# Update Step: 100500/256485, 39.18357798701678%
# tensor(1.7641, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har wat mertend vincicas to Harry ore.
# “Ron his
# m
# ===========================================================================================
# 203
#
#
# ===========================================================================================
# Update Step: 101000/256485, 39.378521161081544%
# tensor(1.7626, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har. ”
# that ther De
# are cland hamrord.”
# “Well —
# ===========================================================================================
# 204
#
#
# ===========================================================================================
# Update Step: 101500/256485, 39.573464335146305%
# tensor(1.7509, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE. . . . . He seer and be wenten.
# “Fireter at the
# ===========================================================================================
# 205
#
#
# ===========================================================================================
# Update Step: 102000/256485, 39.76840750921106%
# tensor(1.7743, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He . Cor teaxpett!”
# The grirely ratch Dalble, and
# ===========================================================================================
# 206
#
#
# ===========================================================================================
# Update Step: 102500/256485, 39.96335068327583%
# tensor(1.7851, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H.. ret and inly pridie don’t he cooking, his groug
# ===========================================================================================
# 207
#
#
# ===========================================================================================
# Update Step: 103000/256485, 40.15829385734059%
# tensor(1.7802, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H . to he He’rff befur.
# “Yeat of Roght,” Hermid pe
# ===========================================================================================
# 208
#
#
# ===========================================================================================
# Update Step: 103500/256485, 40.35323703140535%
# tensor(1.7600, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har ’d bes and Brob. Whan leatzice.
# Haldie some-ow
# ===========================================================================================
# 209
#
#
# ===========================================================================================
# Update Step: 104000/256485, 40.54818020547011%
# tensor(1.7944, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har haireseod, whese at resk your the ronders, Ron
# ===========================================================================================

# %%
generated_seq = synthesize_text(model, 'H', 1000)
print(generated_seq)

# %%
# Prime the network with a context before generation,
# i.e only pass the hidden state forward, not the predicted
# character.
def synthesize_text2(model, prime, length):
    model.eval()
    generated_seq = [char for char in prime]
    hidden = model.init_hidden(1)
    
    #Used to prime the network
    for char in prime:
        x0 = np.zeros(K, dtype=np.float32)
        x0[c2i[char]] = 1
        x0 = torch.from_numpy(x0)
        x0 = x0.view(1,1,K).to(device)
        c, hidden = model(x0, hidden)
    
    c, i, x0 = get_next_char(c)
    generated_seq.append(i)
    
    #x0 = np.zeros(K, dtype=np.float32)
    x0 = x0.view(1,1,K).to(device)
    
    for i in range(length):
        #print("x0 shape: " + str(x0.shape))
        #print("hidden shape: " + str(hidden.shape))
        s, hidden = model(x0, hidden)
        i, c, x0 = get_next_char(s)
        generated_seq.append(c)
    model.train()
    
   # returnString = ""
    
   # for c in generated_seq:
       # returnString += str(c)
    
    return ''.join(generated_seq)

# %%
generated_seq = synthesize_text2(model, 'Harry Potter', 1000)
print(generated_seq)

# %%
import matplotlib.pyplot as plt
xaxis = range(len(lossarr))
print(lossarr)
plt.plot(xaxis,lossarr)
plt.show()

# %%
for str in strarr:
    print(str)
    print()

# %%
# change the name, for saving multiple files
model_name = 'vanilla_rnn_all_books.net'

checkpoint = {'hidden_size': model.hidden_size,
              'n_layers': model.n_layers,
              'state_dict': model.state_dict(),
              'tokens': chars}

with open(model_name, 'wb') as f:
    torch.save(checkpoint, f)

# %%
# Custom Accuracy Measure, measures amount of actual (correct) words generated.
import re
#generated_words = generated_seq.split()
trials = 100
mean_actual_word_count = 0
f = open('goblet_book.txt').read()

for i in range(100):
    generated_words = re.findall(r"[\w']+", synthesize_text2(model, 'Harry Potter', 1000))
    #print(generated_words)
    actual_words_count = 0
    for word in generated_words: 
        if word in f:
            #print("hey! this word matched!")
            #print(word)
            actual_words_count += 1

    actual_words_ratio = actual_words_count/len(generated_words)
    mean_actual_word_count += actual_words_ratio
    #print("synthesized " + str(actual_words_count) + " real words, out of " + str(len(generated_words)) + " attempts.")
    #print("actual word ratio: " + str(actual_words_ratio))

print("Mean of correct words generated: ")
print(mean_actual_word_count/trials)
