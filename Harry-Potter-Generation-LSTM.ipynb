# %%
import torch
from torch import nn
import torch.nn.functional as F 
import numpy as np 
import random

# One-hot encoding matrix with dim (seq_length,K)
# (creating one hot encoded rows for each character in a sequence )
def one_hot(text_seq):
    data = np.zeros((len(text_seq), K), dtype=np.float32)
    for i in range(len(text_seq)):
        char_as_int = text_seq[i]
        data[i][char_as_int] = 1
    return data

def get_all_sequences(book_text):
    # Translate text to integers
    book_as_ints = np.array([c2i[c] for c in book_text])
    n_seq = len(book_as_ints)//seq_length
    book_text = book_text[:n_seq*seq_length]
    batches = []
    for i in range(0, len(book_text), seq_length):
        batches.append(one_hot(book_as_ints[i:i+seq_length]))
    return np.array(batches, dtype=np.float32)

# one_hots = (seq_length, K)
def one_hot_to_txt(one_hots):
    chars = []
    for arr in one_hots:
        idx = np.where(arr == 1)[0][0]
        chars.append(i2c[idx])
    return ''.join(chars)

def one_hot_to_ind(one_hots):
    indices = []
    for arr in one_hots:
        indices.append(np.where(arr==1)[0][0])
    return np.array(indices)

def get_next_char(s):
    s = nn.functional.softmax(s, dim=1)
    l = torch.cumsum(s, dim=1)
    a = random.uniform(0,1)
    ls = (l - a).cpu().detach().numpy()
    #print(ls)
    idx = np.where(ls > 0)
    idx = idx[1][0]
    onehot = np.zeros(K, dtype=np.float32)
    onehot[idx] = 1
    onehot = torch.from_numpy(onehot).view(1,1,K).float().to(device)
    return idx, i2c[idx], onehot

def synthesize_text(model, char, length):
    model.eval()
    generated_seq = [char]
    x0 = np.zeros(K, dtype=np.float32)
    x0[c2i[char]] = 1
    x0 = torch.from_numpy(x0)
    x0 = x0.view(1,1,K).to(device)
    hidden = model.init_hidden(1)
    for i in range(length):
        #print("x0 shape: " + str(x0.shape))
        #print("hidden shape: " + str(hidden.shape))
        s, hidden = model(x0, hidden)
        i, c, x0 = get_next_char(s)
        generated_seq.append(c)
    model.train()
    return ''.join(generated_seq)

# Layered LSTM for character-level generation
class MultiLayerLSTM(nn.Module):
    def __init__(self, input_size, output_size, hidden_size, n_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.n_layers = n_layers
        self.lstm = nn.LSTM(input_size, hidden_size, n_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, len(chars))

    def forward(self, x, hidden):
        # Passing in the input and hidden state into the model and obtaining outputs
        out, hidden = self.lstm(x, hidden)
        # Reshaping the outputs such that it can be fit into the fully connected layer
        out = out.contiguous().view(-1, self.hidden_size)
        out = self.fc(out)

        return out, hidden

    def init_hidden(self, batch_size):
        # This method generates the first hidden state of zeros which we'll use in the forward pass
        # We'll send the tensor holding the hidden state to the device we specified earlier as well
        if cuda_available:
            hidden = (torch.zeros(self.n_layers, batch_size, self.hidden_size).cuda(),
                      torch.zeros(self.n_layers, batch_size, self.hidden_size).cuda())
        else:
            hidden = (torch.zeros(self.n_layers, batch_size, self.hidden_size),
                     torch.zeros(self.n_layers, batch_size, self.hidden_size))
        return hidden

# Saves loss and generted text during training    
lossarr = []
strarr = []
def train(model, n_epochs, clip, debug = 0, steps_during_debug=2):
    model.train()
    update_step = 0
    smooth_loss = 0
    debug = 0
    #print("Numbers of update steps per epoch: " + str(x.shape[0]))
    for epoch in range(1, n_epochs + 1):
        #OBSSS!!! HARDCODED BATCH MIGHT CHANGE LATER
        hidden = model.init_hidden(1)
        for i in range(x.shape[0]):
            if debug: 
                if(i > steps_during_debug): 
                    break    
            # Detatching hidden state from the computational graph 
            # (see truncated back propagation through time) such that
            # the graph doesn't become super big, slowing down computations
            # and exploding the gradient. 
            
            # Note however that the hidden state VALUE will still be inherited
            # We just say that it doesn't depend on previous hidden states
            hidden = tuple([each.data for each in hidden])
            #hidden[0].detach_()
            #hidden[1].detach_()
            #hidden[0] = hidden[0].to(device)
            #hidden[1] = hidden[1].to(device)
            
            # Clear gradients between update steps, won't be cleared automatically. 
            opt.zero_grad() 
            
            #Remember that input should have dimensions (batch_size, seq_size, number_of_classes)
            seq = x[i]
            seq = torch.from_numpy(seq).view(1,seq_length,K)
            #if cuda_available: 
            seq = seq.to(device)
            #print("seq shape: " + str(seq.shape))        

            #Should have shape (25) (not (25,80))
            target = y[i]
            target = one_hot_to_ind(target)
            target = torch.from_numpy(target)
            target = target.to(device)
            #print("target shape: " + str(target.shape))

            output, hidden = model(seq, hidden)
            loss = criterion(output, target)
            
            if update_step == 0:
                smooth_loss = loss
            else:
                smooth_loss = smooth_loss*0.999 + loss*0.001
            if update_step%500 == 0:
                lossarr.append(smooth_loss.item())
                print("\n\n===========================================================================================")
                print("Update Step: " + str(update_step) +"/" + str(x.shape[0]) + ", " + str((update_step/x.shape[0])*100) +"%")
                print(str(smooth_loss))
                print("========================================= TEXT ============================================")
                print(synthesize_text(model, 'H', 50))
                print("===========================================================================================")
            if update_step%5000 == 0:
                strarr.append(synthesize_text(model, 'H', 50))
            
            # BPTT 
            loss.backward() 
            # Clip gradients such that they don't explode
            nn.utils.clip_grad_norm_(model.parameters(), clip) 
            # Update the gradients
            opt.step() 
            update_step += 1
    model.eval()

# %%
cuda_available = torch.cuda.is_available()
if cuda_available:
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("Running on: " + str(device))

# Open file and get text
file = open("Clean_All_Books.txt", "r", encoding="utf8")
book = file.read()
file.close()

# Tokenize chars in text
chars = list(set(book))
chars.sort()
i2c = dict(enumerate(chars))
c2i = {i2c[i]: i for i in i2c.keys()}

# Hyper-parameters
# Num hidden nodes
m = 100
# Batch Size (batch meaning same as lab)
seq_length = 25
# Number of chars
K = len(chars)
# Learning rate
eta = 0.1
      
model = MultiLayerLSTM(input_size = K, output_size = K, hidden_size = m, n_layers=2)
model.to(device)
criterion = nn.CrossEntropyLoss()
opt = torch.optim.Adagrad(model.parameters(), lr=eta)
# model.parameters are all params e.g U, V, b, c etc, see print below
#for param in list(model.parameters()):
#    print(param.shape)
x = get_all_sequences(book)
#print(np.shape(x))
#print(one_hot_to_txt(x[0]))
# If even number of chars (in relation to seq_length), first char will be last target
y = get_all_sequences(book[1:] + book[0])
# Out:
# Running on: cuda

# %%
train(model, 2, 5)
# Out:
# ===========================================================================================
# Update Step: 0/256485, 0.0%
# tensor(4.5543, device='cuda:0', grad_fn=<NllLossBackward>)
# ========================================= TEXT ============================================
# H:tC7DyFII5“gu”l-lI!I65f—0.M□>“; p
# *~X>q!’aVkJYqX?*
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 500/256485, 0.1949431740647601%
# tensor(3.9042, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hun., Mte, luojmbatodlebdy sht,
# imm’w  ghs ir
# uns,
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 1000/256485, 0.3898863481295202%
# tensor(3.3052, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HwB. ot ther weoon .
# thoye
# sror Phobo oe
# Oe’tm
#
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 1500/256485, 0.5848295221942803%
# tensor(2.8571, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Haho doo
# ritkonpwteed his hithy Mn a, be Afeary Ful
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 2000/256485, 0.7797726962590404%
# tensor(2.5356, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HHa,, “Woncon mair then stert. “Yesade teed apworeg
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 2500/256485, 0.9747158703238007%
# tensor(2.2898, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Ha. Oars Patt,, a theed w- pandnars pettir Harry ha
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 3000/256485, 1.1696590443885606%
# tensor(2.1514, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Haund of cals,”
# sech new, and
# there thills might
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 3500/256485, 1.3646022184533209%
# tensor(2.0729, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hon’ he he ter into e’ly come. OAnt Mn row amtle wa
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 4000/256485, 1.5595453925180809%
# tensor(2.0179, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Haard
# had it
# the
# ed coudand the a wingly and “ou
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 4500/256485, 1.754488566582841%
# tensor(1.9549, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hmina’ bat. Taste,” said to —
# quizkret. said mumke
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 5000/256485, 1.9494317406476014%
# tensor(1.9134, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hqurarly his
# then’t mavopen. He so ceingone aspeos
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 5500/256485, 2.1443749147123614%
# tensor(1.8470, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hagwing
# his padant xeophing house. At hened to Cil
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 6000/256485, 2.339318088777121%
# tensor(1.8184, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H’ rormy, Hagrey. He cart fer shicp stec.
# door peo
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 6500/256485, 2.534261262841882%
# tensor(1.7852, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He Dom
#
# Nought?”
# Harry’s agaward bace a grait.
# “W
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 7000/256485, 2.7292044369066417%
# tensor(1.7811, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary he gat juggere the yourcele
# up.
# A to thape’s
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 7500/256485, 2.924147610971402%
# tensor(1.7771, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H) “Abloon to
# in a gorfun to wood. Popbe to know t
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 8000/256485, 3.1190907850361618%
# tensor(1.7600, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harght,
# Flincily. shiid. Apmowe a thors
# roor, wul
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 8500/256485, 3.314033959100922%
# tensor(1.7289, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hw-Thhyre Heacklet, Harry hald
# feemebles’s about o
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 9000/256485, 3.508977133165682%
# tensor(1.6829, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hne whicky. “Aldone, Flying down I handest-” caul a
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 9500/256485, 3.7039203072304425%
# tensor(1.6621, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hald at posss, incat him. Cound of tears looks spre
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 10000/256485, 3.8988634812952028%
# tensor(1.6565, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hurme — aw a see you,” jeinged heer
# sill thands ou
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 10500/256485, 4.093806655359963%
# tensor(1.6221, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hm:” said Itardly Wo’d meveres found how hurrideker
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 11000/256485, 4.288749829424723%
# tensor(1.6244, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H7rry,” exkicch her as he could of the sond bloor,
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 11500/256485, 4.483693003489483%
# tensor(1.6186, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HR RAn, Ron free forget
# to tond by to, uld at the
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 12000/256485, 4.678636177554242%
# tensor(1.6256, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hay he tall mary. The thermery, the
# counte sok as
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 12500/256485, 4.873579351619003%
# tensor(1.5832, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry you’ll  than of my.
# Thees, but
# anywhore in
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 13000/256485, 5.068522525683764%
# tensor(1.5703, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry’s ressed un all very stair for.
# “Bet. “And N
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 13500/256485, 5.263465699748523%
# tensor(1.5740, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# He.” he swotted. “row’, see to fer dighol brous!.”
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 14000/256485, 5.458408873813283%
# tensor(1.5605, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hcamaps was boy the bis drowit wiedly to purficy in
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 14500/256485, 5.653352047878044%
# tensor(1.5480, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HH ROWHmDrE‘
# yeh gall.”
# “
# There’s lanin’ wanted
# O
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 15000/256485, 5.848295221942804%
# tensor(1.5577, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hfo had our of the canmgran,
# save blood op is look
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 15500/256485, 6.043238396007563%
# tensor(1.5364, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H he’s thid say
# had coster downd ears came to plic
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 16000/256485, 6.2381815700723235%
# tensor(1.5116, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry,” said
# Sore to can to neesles
# Flock, if can
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 16500/256485, 6.433124744137084%
# tensor(1.5151, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hult jute suddledridy notes loth of fritch Noxtect
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 17000/256485, 6.628067918201844%
# tensor(1.5093, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hwe strang lookidy alnots and have mace on
# the Cou
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 17500/256485, 6.823011092266603%
# tensor(1.5212, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hy to the,
# for ...” Harry didn’t said, and Hagrid
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 18000/256485, 7.017954266331364%
# tensor(1.5540, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hen’t sometised to scanl’t senNenifer his stound it
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 18500/256485, 7.212897440396125%
# tensor(1.5566, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HD, Mr
# as I know care with he
# to maging, he soy qu
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 19000/256485, 7.407840614460885%
# tensor(1.5701, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hsn
# his gleat not was fatemelfighing his beasn’s h
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 19500/256485, 7.602783788525645%
# tensor(1.5414, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HWr you feen on the window yes prein, it off the gr
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 20000/256485, 7.7977269625904055%
# tensor(1.5747, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry while been things cight, yin. As out of Mr. E
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 20500/256485, 7.992670136655165%
# tensor(1.5882, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hvelly way to cime it left to to him a out. Then  t
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 21000/256485, 8.187613310719925%
# tensor(1.5852, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H” Ron
# withten han, into it and stullion whichered
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 21500/256485, 8.382556484784685%
# tensor(1.5821, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har hemelly!”
# Uncle Vernon whisper at Harry of his
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 22000/256485, 8.577499658849446%
# tensor(1.5728, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Has I’m say Mrs. Somethur. Theure not beede, You me
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 22500/256485, 8.772442832914205%
# tensor(1.5647, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hard
# PreWe
# scobehay looked Crossie — no station f
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 23000/256485, 8.967386006978966%
# tensor(1.5819, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HG. I was horred out, and Ron green feet fingart ag
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 23500/256485, 9.162329181043726%
# tensor(1.5891, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry there to thrieps tanaily, glignting pipboniss
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 24000/256485, 9.357272355108485%
# tensor(1.5857, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HAyment pairten I was puttle — ”
# “What’s start tha
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 24500/256485, 9.552215529173246%
# tensor(1.5546, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hal and there’s a lood glitt, Wearly hang,” said Ti
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 25000/256485, 9.747158703238005%
# tensor(1.5621, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry’s ears that there was but a ned the creasen l
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 25500/256485, 9.942101877302765%
# tensor(1.5917, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hars Ron what themeile yet goldhily where batnood,
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 26000/256485, 10.137045051367528%
# tensor(1.5769, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hr Giws! Filce der, Harryry in my about the fised,
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 26500/256485, 10.331988225432287%
# tensor(1.5605, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H.. . Wall ’eve onge and Ron, and
# Sryive he was he
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 27000/256485, 10.526931399497046%
# tensor(1.5352, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hard not he’s  can to move what ailacone to get als
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 27500/256485, 10.721874573561808%
# tensor(1.5360, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry’s line to an when Lockhart. Back thick pamute
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 28000/256485, 10.916817747626567%
# tensor(1.5167, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hboly it strieging a one an itewed blick, toward th
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 28500/256485, 11.111760921691328%
# tensor(1.4976, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H’ gone on
# them’s , some litter, his nover tere
# 2
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 29000/256485, 11.306704095756087%
# tensor(1.5093, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H’s He momeI ear!” He muntigam. “Foles for that let
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 29500/256485, 11.501647269820847%
# tensor(1.5088, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H- Ron, Snit’ll knop a zeartent,
# our out been at t
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 30000/256485, 11.696590443885608%
# tensor(1.5102, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hn been again at he happele.
# Professor met, Harry
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 30500/256485, 11.891533617950367%
# tensor(1.5004, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HDLL”
# “We’re not belet of drys!”
# Harry Busned she
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 31000/256485, 12.086476792015127%
# tensor(1.4947, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hal and Zon’t nedged at like one was kept a upsing
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 31500/256485, 12.281419966079888%
# tensor(1.4822, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hur
# repemfrusoliby
# Pot we
# may?” Ron Chripely.
# B
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 32000/256485, 12.476363140144647%
# tensor(1.4837, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hard Harry, his cold the rose of Hermione unlowed t
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 32500/256485, 12.671306314209406%
# tensor(1.4716, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hard Ron peased to echived him selpact, He didn’t w
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 33000/256485, 12.866249488274168%
# tensor(1.4498, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hy. Weasley’s going facien told silen off out of Ha
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 33500/256485, 13.061192662338927%
# tensor(1.4615, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H’’d beel Didneed at ...
# Eirsy to vaiten’t in
# Cla
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 34000/256485, 13.256135836403688%
# tensor(1.4452, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hrrw looe’s and greast
# lent, curtlent.
# “Drag — ”
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 34500/256485, 13.451079010468447%
# tensor(1.4392, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Han stair.”
# “Demmome awaying they betose just knoc
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 35000/256485, 13.646022184533207%
# tensor(1.4307, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hards George is!” Harry, loody have floing onto the
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 35500/256485, 13.840965358597968%
# tensor(1.4138, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hard, and bestanise idnoway, somewheing. . . . in,
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 36000/256485, 14.035908532662727%
# tensor(1.4210, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Huh, I’d hele, as George.”
# They loaked
# his was so
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 36500/256485, 14.230851706727488%
# tensor(1.4472, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har of
# yhe day yeh knee to Nealling about you,” sa
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 37000/256485, 14.42579488079225%
# tensor(1.4482, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HIAn’t orfither Lockhart’s mouth,” he sweam that so
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 37500/256485, 14.62073805485701%
# tensor(1.4428, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HArm Drayegain,” said Ron hagiculfolied at the dryi
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 38000/256485, 14.81568122892177%
# tensor(1.4497, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry,”
# Harry odd and
# Riddle time. they under mea
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 38500/256485, 15.010624402986531%
# tensor(1.4953, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HVGEY OCO AT HqLever. We’lv gone the and hurry
# on
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 39000/256485, 15.20556757705129%
# tensor(1.5016, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry,”
# Harry were canding a wall-stanciny, but th
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 39500/256485, 15.40051075111605%
# tensor(1.4948, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hh kitter, the other Petunized rarted his farched y
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 40000/256485, 15.595453925180811%
# tensor(1.5079, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hmiously as Mr. Get
# I’m purple, and Weasley penple
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 40500/256485, 15.79039709924557%
# tensor(1.5355, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry for then out
# fan futime up to sout — ’ed — b
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 41000/256485, 15.98534027331033%
# tensor(1.5558, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HY EARL
# — you’ve keen, and stuar throum of Harry,
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 41500/256485, 16.18028344737509%
# tensor(1.5237, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Ham if Uncrey nercased with the kind.
# “As zed fad
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 42000/256485, 16.37522662143985%
# tensor(1.4848, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Ht things, poarite,
# Mr. Peressuaded the talled to
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 42500/256485, 16.57016979550461%
# tensor(1.4560, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HM FU An In croiss off at the Drowd Did, fenlil — ”
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 43000/256485, 16.76511296956937%
# tensor(1.4244, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry just thim.”
# They  girs all the dakening the
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 43500/256485, 16.96005614363413%
# tensor(1.4056, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HT EAn’S no back the day? AEd Ern!”
# They thing the
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 44000/256485, 17.15499931769889%
# tensor(1.4564, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry’s knappien on it, wing. A dreaving to the man
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 44500/256485, 17.349942491763652%
# tensor(1.4479, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry
# keely of thet ap by
# however bendond for you
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 45000/256485, 17.54488566582841%
# tensor(1.4438, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry ressed now
# killing
# ad it was a kill.
# “What
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 45500/256485, 17.73982883989317%
# tensor(1.4353, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hagidar, an’ nell, and belaw bone
# him,” said Snape
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 46000/256485, 17.934772013957932%
# tensor(1.4475, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H. No? Professor ... new facatelet.
# “Durile if Man
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 46500/256485, 18.12971518802269%
# tensor(1.4613, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hce Ron beshing their nextver while
# But Hermioneed
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 47000/256485, 18.32465836208745%
# tensor(1.4219, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HV Gomobled.
# “Not catertank.” a mutchever frowning
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 47500/256485, 18.519601536152212%
# tensor(1.4047, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hh. “I keep bor countargutters inle time phorsny bu
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 48000/256485, 18.71454471021697%
# tensor(1.4113, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary not realies.”
# He was a ear up insarely. “Set
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 48500/256485, 18.90948788428173%
# tensor(1.4050, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H” Craying dorgin for the first been whet
# to sayin
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 49000/256485, 19.104431058346492%
# tensor(1.4047, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har anyonight and jast, much, still, try to came Sn
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 49500/256485, 19.29937423241125%
# tensor(1.4462, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HB‘Demobbeard. She sawn’s there stadking of I if on
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 50000/256485, 19.49431740647601%
# tensor(1.4737, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Ht.
# “It’s voith
# that
# the magid, well feet came t
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 50500/256485, 19.689260580540772%
# tensor(1.4491, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry andrming, did what Harry into the
# points
#
# L
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 51000/256485, 19.88420375460553%
# tensor(1.4594, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry devestarm. Mr.
# Firsqoly. He was him an boy
#
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 51500/256485, 20.079146928670294%
# tensor(1.4264, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HFM LNGOMuaUS LwGonagan hame
# with with Common the
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 52000/256485, 20.274090102735055%
# tensor(1.4180, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HR
# SMmGmubas borishe wead!” said Hermione foruggen
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 52500/256485, 20.469033276799813%
# tensor(1.4092, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hor Weasley, in her.”
# “If he want a late-your they
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 53000/256485, 20.663976450864574%
# tensor(1.4194, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HR PERRDEK
# AODRESSHS ANNSWONONL — In’t might — or
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 53500/256485, 20.858919624929335%
# tensor(1.4238, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry will fool
# of the finely awoFe freaned, Noxio
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 54000/256485, 21.053862798994093%
# tensor(1.4389, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry anweaked all off.
# “Harry, expicer hem!”
# Har
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 54500/256485, 21.248805973058854%
# tensor(1.4175, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry. Harry rays.
# “Now Dean. Everyoberus Snape’s
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 55000/256485, 21.443749147123615%
# tensor(1.4104, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hrs Cload do?”
# “We lo wish them have gag.”
# “Come.
# ===========================================================================================
#
#
# ...
#
#
# ===========================================================================================
# Update Step: 85000/256485, 33.14033959100922%
# tensor(1.3396, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har.”
# Black into up through Harry had back, it com
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 85500/256485, 33.335282765073984%
# tensor(1.3461, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HR OUS.
# And the furccols.  ?” he prepred across. T
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 86000/256485, 33.53022593913874%
# tensor(1.3357, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hr off, the didn’t short on it was movent with so a
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 86500/256485, 33.7251691132035%
# tensor(1.3544, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Ht KIRK YOUN! praving get out a past a couldn’t let
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 87000/256485, 33.92011228726826%
# tensor(1.3534, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary Weasley lyang them hope for Ron for the largin
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 87500/256485, 34.11505546133302%
# tensor(1.3419, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H Harry’s moned, Harry who? Cederatiar let as a lot
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 88000/256485, 34.30999863539778%
# tensor(1.3590, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H... Julotter — I seem — cettery and will
# they wen
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 88500/256485, 34.504941809462544%
# tensor(1.3314, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary Moxtious, askey, it
# clid, much ime nearly loo
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 89000/256485, 34.699884983527305%
# tensor(1.3545, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hurse
# Pigwerniage, and Nevinking enckon’s glassem,
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 89500/256485, 34.89482815759206%
# tensor(1.3789, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry noes you. Canny showning, Harry mearing
# all,
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 90000/256485, 35.08977133165682%
# tensor(1.3615, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HS Kacoous fatury up to one ad all Five much color
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 90500/256485, 35.28471450572158%
# tensor(1.3503, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HONCIL’W CUNT JEPECHY”
# Krum of at the trants with
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 91000/256485, 35.47965767978634%
# tensor(1.3603, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hy” Pere as that Pick and his
# through about hard t
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 91500/256485, 35.6746008538511%
# tensor(1.3502, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary! Huck a. And mereson my stairsned up the you
#
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 92000/256485, 35.869544027915865%
# tensor(1.3667, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HH YOU HCE HISN’ —  She I reavely of I just beamed
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 92500/256485, 36.06448720198062%
# tensor(1.3678, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry, Fley bubbles, he
# dry winder — you, got the
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 93000/256485, 36.25943037604538%
# tensor(1.3446, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HALYEDEODGEW.
# Lupit hundred, was apenared faced ag
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 93500/256485, 36.45437355011014%
# tensor(1.3277, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HS No, IS, go an into the lave from a all you pepor
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 94000/256485, 36.6493167241749%
# tensor(1.3445, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HM! That’s how was you we ...”
# “Where, then turned
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 94500/256485, 36.84425989823966%
# tensor(1.3621, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harry squeaked through the Great Voldly desing him.
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 95000/256485, 37.039203072304424%
# tensor(1.3485, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hve Neville, Harry, thought; the hat to sas no, hop
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 95500/256485, 37.23414624636918%
# tensor(1.3624, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HW. Whee ten all-,” said Bagman and
# said that I wa
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 96000/256485, 37.42908942043394%
# tensor(1.3600, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hary — ”
# Hermione Harry fan perpaser. “Very whose
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 96500/256485, 37.6240325944987%
# tensor(1.3446, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H.. Trought be toul DO H’ Thouse, a second, so disi
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 97000/256485, 37.81897576856346%
# tensor(1.3319, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HN.”
# “Harry Fies here, ’s nose since Klutch. ... A
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 97500/256485, 38.01391894262822%
# tensor(1.3457, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hst the darkhus. It was the boy. Harry which at Hag
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 98000/256485, 38.208862116692984%
# tensor(1.3408, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hmorn reached him, saw
# it, watched
# hopering that
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 98500/256485, 38.403805290757745%
# tensor(1.2840, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HR MAGKULNSVEUM OATCUPESKEWEm,”
# But Ond therear.
#
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 99000/256485, 38.5987484648225%
# tensor(1.2601, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H other? Smmose,” he said. “I toliet,” said Hermion
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 99500/256485, 38.79369163888726%
# tensor(1.2890, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HS FNNK SSE Made that you not recover!” said Hermio
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 100000/256485, 38.98863481295202%
# tensor(1.2965, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HE
# Bsthericular! I’m not connected at the oll that
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 100500/256485, 39.18357798701678%
# tensor(1.3060, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Harl Pamp yet over a musan about Ron, and anything
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 101000/256485, 39.378521161081544%
# tensor(1.3091, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Har Moody; it and rittel, and someHutiver he
# forgo
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 101500/256485, 39.573464335146305%
# tensor(1.2945, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# Hchnely, down on the -mombund
# him. Dumbledore’s fr
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 102000/256485, 39.76840750921106%
# tensor(1.3091, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H... If if they wail,” said “Never behind that spre
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 102500/256485, 39.96335068327583%
# tensor(1.3185, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# H,” said Hermione. He was hige right. That had
# hea
# ===========================================================================================
#
#
# ===========================================================================================
# Update Step: 103000/256485, 40.15829385734059%
# tensor(1.3246, device='cuda:0', grad_fn=<AddBackward0>)
# ========================================= TEXT ============================================
# HArOW’s
# Karkaroor?” said Harry went his creat
# and
# ===========================================================================================

# %%
# Prime the network with a context before generation,
# i.e only pass the hidden state forward, not the predicted
# character.
def synthesize_text2(model, prime, length):
    model.eval()
    generated_seq = [char for char in prime]
    hidden = model.init_hidden(1)
    
    #Used to prime the network
    for char in prime:
        x0 = np.zeros(K, dtype=np.float32)
        x0[c2i[char]] = 1
        x0 = torch.from_numpy(x0)
        x0 = x0.view(1,1,K).to(device)
        c, hidden = model(x0, hidden)
    
    c, i, x0 = get_next_char(c)
    generated_seq.append(i)
    
    #x0 = np.zeros(K, dtype=np.float32)
    x0 = x0.view(1,1,K).to(device)
    
    for i in range(length):
        #print("x0 shape: " + str(x0.shape))
        #print("hidden shape: " + str(hidden.shape))
        s, hidden = model(x0, hidden)
        i, c, x0 = get_next_char(s)
        generated_seq.append(c)
    model.train()
    
   # returnString = ""
    
   # for c in generated_seq:
       # returnString += str(c)
    
    return ''.join(generated_seq)

# %%
generated_seq = synthesize_text(model, 'H', 1000)
print(generated_seq)

# %%
generated_seq = synthesize_text2(model, 'Harry Potter ', 1000)
print(generated_seq)

# %%
import matplotlib.pyplot as plt
xaxis = range(len(lossarr))
plt.plot(xaxis,lossarr)
plt.show()
print(lossarr)

# %%
for str in strarr:
    print(str)
    print()

# %%
# change the name, for saving multiple files
model_name = 'lstm_2_layers_all_books.net'

checkpoint = {'hidden_size': model.hidden_size,
              'n_layers': model.n_layers,
              'state_dict': model.state_dict(),
              'tokens': chars}

with open(model_name, 'wb') as f:
    torch.save(checkpoint, f)

# %%
import re
#generated_words = generated_seq.split()
trials = 100
mean_actual_word_count = 0
f = open('goblet_book.txt').read()

for i in range(100):
    generated_words = re.findall(r"[\w']+", synthesize_text2(model, 'Harry Potter', 1000))
    #print(generated_words)
    actual_words_count = 0
    for word in generated_words: 
        if word in f:
            #print("hey! this word matched!")
            #print(word)
            actual_words_count += 1

    actual_words_ratio = actual_words_count/len(generated_words)
    mean_actual_word_count += actual_words_ratio
    #print("synthesized " + str(actual_words_count) + " real words, out of " + str(len(generated_words)) + " attempts.")
    #print("actual word ratio: " + str(actual_words_ratio))

print("Mean of correct words generated: ")
print(mean_actual_word_count/trials)
